# %% [markdown]
# # **<div align="center"> LOAD DATA & CREATE SUBSETS </div>**

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

project_root = os.path.abspath("..")   
if project_root not in sys.path:
    sys.path.append(project_root)
from src.load_supabase_api import load_all_data
from src.preprocess.export import export_csv
from src.preprocess.run_pipeline import run_preprocess
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### **Load Data**

# %%
# Load data
df = load_all_data()
df.head()
# Out:
#    cryptocurrency_id                 date  price_usd    market_cap  \
# 0                  1  2025-02-05T12:03:40    97864.0  1.940960e+12
# 1                  1  2025-02-06T12:05:49    99038.0  1.960400e+12
# 2                  1  2025-02-07T12:17:58    97683.0  1.932660e+12
# 3                  1  2025-02-10T12:07:28    97676.0  1.937410e+12
# 4                  1  2025-02-11T12:41:21    98094.0  1.944580e+12
#
#          volume    change cryptocurrency_name
# 0  6.365740e+10 -1.048090             bitcoin
# 1  4.243940e+10  1.304760             bitcoin
# 2  4.612790e+10 -1.056850             bitcoin
# 3  3.885940e+10  0.769589             bitcoin
# 4  2.812790e+10  0.254369             bitcoin

# %%
# Export csv
export_csv(df, '../Data/raw/db_04022026.csv', include_index = False)

# %% [markdown]
# ### **Create Subsets for each Cryptocurrency**

# %%
run_preprocess("../config/preprocess.yaml")
# Out:
# Preprocess completed
